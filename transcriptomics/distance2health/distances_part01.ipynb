# %% [markdown]
# This script quantifies the distance from 2D and 3D cultures wrt. healthy cartilage obtained from GSE114007.

# %%
import pandas

# %% [markdown]
# # user-defined variables

# %%
healthy_data_file = '/Users/adrian/research/akureyri/data/GSE114007_normal_normalized.counts.txt'
cultures_data_file = '/Users/adrian/research/akureyri/results/sleuth_pipeline/sleuth_scaled_reads_bygene.csv'

annotation_file = '/Users/adrian/research/akureyri/results/deseq2_pipeline/annotation.tsv'

results_file = '/Users/adrian/research/akureyri/results/distances/expression.tsv'

# %% [markdown]
# # read info

# %%
hdf = pandas.read_csv(healthy_data_file, sep='\t', index_col=0)
hdf.drop(['Average Normal', 'Max'], axis=1, inplace=True)

# %%
cdf = pandas.read_csv(cultures_data_file, sep='\t', index_col=0)

# %%
annotation = pandas.read_csv(annotation_file, sep='\t', index_col=0)

# %% [markdown]
# # analysis

# %%
healthy_symbols = hdf.index
print(healthy_symbols)
# Out:
# Index(['FN1', 'COMP', 'MALAT1', 'CHI3L2', 'CLU', 'DCN', 'PRELP', 'CILP',
#        'CHI3L1', 'GPX3',
#        ...
#        'XAGE1E', 'XAGE2', 'XAGE2B', 'XGPY2', 'XKRY', 'XKRY2', 'ZBED1',
#        'ZNF658B', 'ZNF705B', 'ZNF705D'],
#       dtype='object', name='symbol', length=23710)

# %%
ensembl_ids = cdf.index
print(ensembl_ids)
# Out:
# Index(['ENSG00000000003', 'ENSG00000000005', 'ENSG00000000419',
#        'ENSG00000000457', 'ENSG00000000460', 'ENSG00000000938',
#        'ENSG00000000971', 'ENSG00000001036', 'ENSG00000001084',
#        'ENSG00000001167',
#        ...
#        'ENSG00000291317', 'ENSG00000292430', 'ENSG00000293527',
#        'ENSG00000293542', 'ENSG00000293543', 'ENSG00000293546',
#        'ENSG00000293548', 'ENSG00000293550', 'ENSG00000293552',
#        'ENSG00000293553'],
#       dtype='object', length=39521)

# %%
annotation.head()
# Out:
#   ensembl_transcript_id  ensembl_gene_id external_gene_name gene_biotype  \
# 1       ENST00000387314  ENSG00000210049              MT-TF      Mt_tRNA
# 2       ENST00000389680  ENSG00000211459            MT-RNR1      Mt_rRNA
# 3       ENST00000387342  ENSG00000210077              MT-TV      Mt_tRNA
# 4       ENST00000387347  ENSG00000210082            MT-RNR2      Mt_rRNA
# 5       ENST00000386347  ENSG00000209082             MT-TL1      Mt_tRNA
#
#                                          description
# 1  mitochondrially encoded tRNA-Phe (UUU/C) [Sour...
# 2  mitochondrially encoded 12S rRNA [Source:HGNC ...
# 3  mitochondrially encoded tRNA-Val (GUN) [Source...
# 4  mitochondrially encoded 16S rRNA [Source:HGNC ...
# 5  mitochondrially encoded tRNA-Leu (UUA/G) 1 [So...

# %% [markdown]
# ## mapp ids

# %%
# %%time
# this block takes circa 3 min

print(len(healthy_symbols))
rosetta = {}
for symbol in healthy_symbols:
    mini = annotation[annotation['external_gene_name'] == symbol]
    results = list(set(mini['ensembl_gene_id']))
    
    if len(results) == 1:
        rosetta[results[0]] = symbol
    if len(results) > 1:
        #print('WARNING: multiple ({}) mapping for {}: {}'.format(len(results), symbol, results[:3]))
        # check how many ensembl id I have in my expression df
        bi_results = []
        for result in results:
            if result in ensembl_ids:
                bi_results.append(result)
        if len(bi_results) == 1:
            #print('fixed multiple mapping')
            rosetta[results[0]] = symbol
        if len(bi_results) > 1:
            print('WARNING: multiple ({}) mapping for {}: {}. Dropping altogether.'.format(len(bi_results), 
                                                                                           symbol, bi_results[:3]))
print(len(rosetta))
# Out:
# 23710
# WARNING: multiple (2) mapping for MATR3: ['ENSG00000280987', 'ENSG00000015479']. Dropping altogether.
# WARNING: multiple (2) mapping for SPATA13: ['ENSG00000182957', 'ENSG00000228741']. Dropping altogether.
# WARNING: multiple (2) mapping for HERC3: ['ENSG00000138641', 'ENSG00000287542']. Dropping altogether.
# WARNING: multiple (2) mapping for PRICKLE2-AS1: ['ENSG00000241111', 'ENSG00000241572']. Dropping altogether.
# WARNING: multiple (2) mapping for POLR2J3: ['ENSG00000168255', 'ENSG00000285437']. Dropping altogether.
# WARNING: multiple (2) mapping for PINX1: ['ENSG00000254093', 'ENSG00000258724']. Dropping altogether.
# WARNING: multiple (2) mapping for PDE8B: ['ENSG00000284762', 'ENSG00000113231']. Dropping altogether.
# WARNING: multiple (2) mapping for DNAJC9-AS1: ['ENSG00000236756', 'ENSG00000227540']. Dropping altogether.
# WARNING: multiple (2) mapping for PDE4C: ['ENSG00000105650', 'ENSG00000285188']. Dropping altogether.
# WARNING: multiple (2) mapping for ARMCX5-GPRASP2: ['ENSG00000271147', 'ENSG00000286237']. Dropping altogether.
# WARNING: multiple (2) mapping for C4orf36: ['ENSG00000163633', 'ENSG00000285458']. Dropping altogether.
# WARNING: multiple (2) mapping for NOX5: ['ENSG00000255346', 'ENSG00000290203']. Dropping altogether.
# WARNING: multiple (2) mapping for ELFN2: ['ENSG00000243902', 'ENSG00000166897']. Dropping altogether.
# WARNING: multiple (2) mapping for SIGLEC5: ['ENSG00000105501', 'ENSG00000268500']. Dropping altogether.
# WARNING: multiple (2) mapping for SFTA3: ['ENSG00000229415', 'ENSG00000257520']. Dropping altogether.
# 20420
# CPU times: user 2min 59s, sys: 115 ms, total: 2min 59s
# Wall time: 3min

# %% [markdown]
# ## join dataframes

# %%
df = pandas.DataFrame.from_dict(rosetta, orient='index', columns=['symbol'])
print(df.shape)
df.head()
# Out:
# (20420, 1)
#                  symbol
# ENSG00000115414     FN1
# ENSG00000105664    COMP
# ENSG00000251562  MALAT1
# ENSG00000064886  CHI3L2
# ENSG00000120885     CLU

# %%
new = df.join(hdf, on='symbol')
print(new.shape)
new.head()
# Out:
